# %%
import pandas as pd
import matplotlib.pyplot as plt

data = pd.read_csv('/media/chen/Data/programme/Visual/SummerStudy/BigDeal/output.txt',sep=' ',header=None)

len = data.shape[0]
plt.figure()
plt.plot([i for i in range(len)],data[0],label='0')
plt.ylim(0, 200000)
plt.figure()
plt.plot([i for i in range(len)],data[1],label='1')
plt.ylim(0, 10000)
plt.figure()
plt.plot([i for i in range(len)],data[1],label='1')
plt.ylim(0, 1000)
plt.figure()
plt.scatter([i for i in range(len)],data[1],label='1', s=2)
plt.ylim(0, 5000)
# Out:
# (0.0, 5000.0)
